# %% [markdown]
# # TASK4. 추가적인 탐색적 데이터 분석(EDA)
#
# 다양한 모델을 활용해 EDA를 분석하는 과정입니다. 다음 예제는 분석 참고용입니다.
#
# ## 0. 환경변수 설정

# %%
from google.cloud import bigquery
import os

client = bigquery.Client()

PROJECT_ID = client.project
DATASET_NAME = "cymbal"
TABLE_NAME = "customer_review"
BUCKET_NAME = "qwiklabs-gcp-01-416cbdc92d8c-bucket" #qwiklabs-gcp-01-416cbdc92d8c-bucket
TASK4_1_NEW_TABLE_NAME = "embeded_table"
TASK4_2_NEW_TABLE_NAME = "cgenf_table" #category enforcement table
TASK4_3_NEW_TABLE_NAME = "improv_table" #improvement enforcement table
TASK4_1_MODEL_NAME = "embedding_model"
TASK4_2_MODEL_NAME = "gemini_model"
TASK4_3_MODEL_NAME = "gemini_model"
TASK4_5_MODEL_NAME = "gemini_model"

# %% [markdown]
# ## 1. 텍스트 임베딩 모델 생성 및 유사도 검색

# %%
task4_1_1_query = f"""
 CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_NAME}.{TASK4_1_NEW_TABLE_NAME}` AS
 SELECT * FROM ML.GENERATE_EMBEDDING(
  MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_1_MODEL_NAME}`,
  (SELECT review_text AS content, customer_id, customer_review_id
   FROM `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}`
  )
)
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_1_1_query
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
task4_1_2_query = f"""
  SELECT
    t.content,
    t.customer_id,
    t.customer_review_id,
    # 코사인 유사도 점수 (1에 가까울수록 의미적으로 유사함)
    1 - ML.DISTANCE(
      t.ml_generate_embedding_result,
      query_embed.ml_generate_embedding_result,
      'COSINE'
    ) AS similarity_score
  FROM
    `bq-agent-kr.cymbal.embeded_table` AS t,
    ML.GENERATE_EMBEDDING(
    MODEL `bq-agent-kr.cymbal.embedding_model`,
    (SELECT '품질 불량' AS content) # 여기에 검색어를 입력합니다.
    ) AS query_embed
  ORDER BY similarity_score DESC
  LIMIT 5
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_1_2_query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                              content  customer_id  \
# 0  The product quality is very poor. I definitely...         8857
# 1  The product quality is very poor. I definitely...         8858
# 2  The product quality is very poor. I definitely...        10008
# 3  The product quality is very poor. I definitely...         4533
# 4  The product quality is very poor. I definitely...         9823
#
#    customer_review_id  similarity_score
# 0                 249          0.764613
# 1                 203          0.764613
# 2                 209          0.764613
# 3                 242          0.764613
# 4                 201          0.764613

# %% [markdown]
# ## 2. 각 리뷰별 카테고리 군집화 데이터 보강하기
#
# 어떻게 데이터가 보강되는지 코드와 예시를 보고 이해합니다.

# %%
task4_2_1_query = f"""
  SELECT
    customer_review_id,
    customer_id,
    issue_category
  FROM
    AI.GENERATE_TABLE(
      MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_2_MODEL_NAME}`,
      (
        SELECT
          t.customer_id,
          t.customer_review_id,
          t.review_text,
          CONCAT(
            '''
            부정적인 리뷰로 판단된 경우 분석해서 문제점을 카테고리화해서 분류하려고 해
  .           다음 카테고리 중 하나를 택해서 분류해줘
            **품질불량, 배송문제, 기대미충족, 단순변심, 결제문제, 응대문제, 기타**
              긍정적인 리뷰로 판단된 경우 **해당없음**으로 분류해주면 돼.
              분석할 리뷰:
            ''',
            t.review_text
          ) AS prompt
        FROM
          `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}` AS t
        WHERE
          t.rating < 3
      ),
      STRUCT(
        "issue_category STRING" AS output_schema,
        8192 AS max_output_tokens
      )
    )

"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_2_1_query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_review_id  customer_id issue_category
# 0                  221         5516           품질불량
# 1                  202        10959           배송문제
# 2                  227        10387          기대미충족
# 3                  235         6540           배송문제
# 4                  206         5330           품질불량
# 5                  241         3407           응대문제
# 6                  245         5327          기대미충족
# 7                  233         5919          기대미충족
# 8                  207         5424           품질불량
# 9                  210        10877          기대미충족
# 10                 240         5744           품질불량
# 11                 208         9943           응대문제
# 12                 243         6531           품질불량
# 13                 244         9141          기대미충족
# 14                 247         4764           배송문제
# 15                 216         8206           품질불량
# 16                 223         8496           품질불량
# 17                 215         8887           배송문제
# 18                 213         8686          기대미충족
# 19                 214         8871          기대미충족
# 20                 238         5975          기대미충족
# 21                 219         6355           품질불량
# 22                 222        10769          기대미충족
# 23                 237        10661          기대미충족
# 24                 228         5480           배송문제
# 25                 224        10920          기대미충족
# 26                 225        10003           응대문제
# 27                 212         6418           품질불량
# 28                 220        10842          기대미충족
# 29                 234        10669          기대미충족
# 30                 250         7170           품질불량
# 31                 217         5629          기대미충족
# 32                 232         2334           응대문제
# 33                 211         2780           품질불량
# 34                 229         5957           품질불량
# 35                  71         1071           해당없음
# 36                 204         7272          기대미충족
# 37                 231         1195          기대미충족
# 38                 205         4264          기대미충족
# 39                 236        10500          기대미충족
# 40                 239         4462           품질불량
# 41                 248         8710          기대미충족
# 42                 226         8533           품질불량
# 43                 230         6436           품질불량
# 44                 246         4606           품질불량
# 45                 218         2057           품질불량

# %% [markdown]
# 해당 결과를 아래 과정을 통해 테이블로 생성합니다.

# %%
task4_2_2_query = f"""
CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_NAME}.{TASK4_2_NEW_TABLE_NAME}` AS (
  SELECT
    customer_review_id,
    customer_id,
    issue_category
  FROM
    AI.GENERATE_TABLE(
      MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_2_MODEL_NAME}`,
      (
        SELECT
          t.customer_id,
          t.customer_review_id,
          t.review_text,
          CONCAT(
            '''
            부정적인 리뷰로 판단된 경우 분석해서 문제점을 카테고리화해서 분류하려고 해
  .           다음 카테고리 중 하나를 택해서 분류해줘
            **품질불량, 배송문제, 기대미충족, 단순변심, 결제문제, 응대문제, 기타**
              긍정적인 리뷰로 판단된 경우 **해당없음**으로 분류해주면 돼.
              분석할 리뷰:
            ''',
            t.review_text
          ) AS prompt
        FROM
          `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}` AS t
        WHERE
          t.rating < 3
      ),
      STRUCT(
        "issue_category STRING" AS output_schema,
        8192 AS max_output_tokens
      )
    )

)

"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_2_2_query
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3. 고객들의 리뷰를 분석해 개선점을 정의한 데이터 보강하기
#
# 해당 단계에서는 위의 코드와 다른 함수로 데이터 보강을 하는 방법을 보고 이해합니다.

# %%
task4_3_1_query = f"""
  SELECT
    generated_output.customer_id,
    generated_output.customer_review_id,
    generated_output.ml_generate_text_result.candidates[0].content.parts[0].text AS improvement_points
  FROM
  ML.GENERATE_TEXT(
    MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_3_MODEL_NAME}`,
    (SELECT
  customer_id,
  customer_review_id,
  CONCAT(
    '''
    다음 리뷰를 참고해서 고객이 불만족한 부분을 개선할 수 있는 구체적인 방안 1개와 고객이 좋아할 법한 상품 특성을 1개 제시해줘 양식은 다음과 같아. 양식을 무조건 지켜서 작성해줘.
    개선방안 :
    고객이 좋아할 법한 특성 :
  참고할 리뷰내용 :
  ''', review_text) AS prompt
  FROM `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}`
  WHERE rating < 3),
  STRUCT(
    0.2 AS temperature,
    2048 AS max_output_tokens )
  ) AS generated_output
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_3_1_query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id  customer_review_id  \
# 0          5516                 221
# 1          8496                 223
# 2          8887                 215
# 3          8686                 213
# 4          6540                 235
# 5          5330                 206
# 6          3407                 241
# 7          5327                 245
# 8          5919                 233
# 9          5424                 207
# 10        10877                 210
# 11         5744                 240
# 12         9943                 208
# 13         6531                 243
# 14         9141                 244
# 15         4764                 247
# 16         8206                 216
# 17        10959                 202
# 18        10387                 227
# 19         8871                 214
# 20         5975                 238
# 21         6355                 219
# 22        10769                 222
# 23        10661                 237
# 24         5480                 228
# 25        10920                 224
# 26        10003                 225
# 27         6418                 212
# 28        10842                 220
# 29        10669                 234
# 30         7170                 250
# 31         5629                 217
# 32         2334                 232
# 33         2780                 211
# 34         5957                 229
# 35         1071                  71
# 36         7272                 204
# 37         1195                 231
# 38         4264                 205
# 39        10500                 236
# 40         4462                 239
# 41         8710                 248
# 42         8533                 226
# 43         6436                 230
# 44         4606                 246
# 45         2057                 218
#
#                                    improvement_points
# 0   "개선방안 : 제품의 핵심 부품에 더 견고한 소재를 사용하고, 생산 과정에서 품질 ...
# 1   "개선방안 : 제품의 핵심 부품 소재를 고급화하여 내구성을 획기적으로 개선한다.\n...
# 2   "개선방안 : 배송 지연 보상 정책 도입 및 실시간 배송 추적 시스템 강화\n고객이...
# 3   "개선방안 : 제품의 핵심 기능을 처음 사용하는 고객을 위해 단계별로 따라 할 수 ...
# 4   "개선방안 : 제품 포장재를 더 견고한 소재로 변경하고, 포장 과정에 대한 품질 검...
# 5   "개선방안 : 생산 공정 전반에 걸쳐 품질 검수 단계를 강화하여 불량률을 낮추고, ...
# 6   "개선방안 : 고객 문의 처리 절차를 간소화하고, 각 단계별 처리 시간을 단축하기 ...
# 7   "개선방안 : 제품 상세 페이지에 실제 사용 환경을 반영한 사진이나 영상을 추가하여...
# 8   "개선방안 : 경쟁사 제품 대비 핵심 기능의 성능을 대폭 강화하여 고객이 체감하는 ...
# 9   "개선방안 : 핵심 부품의 재질을 고급화하여 제품의 내구성을 강화하고, 이를 통해 ...
# 10  "개선방안 : 제품 상세 페이지에 실제 사용 환경이나 예상되는 한계점을 명확히 기재...
# 11  "개선방안 : 제품의 취약 부분을 보강하고, 충격에 강한 고품질 소재로 변경하여 내...
# 12  "개선방안 : 고객 문의 접수 후 24시간 이내 1차 답변 제공 및 72시간 이내 ...
# 13  "개선방안 : 출시 전 기능 테스트 강화\n고객이 좋아할 법한 특성 : 안정적인 기...
# 14  "개선방안 : 상품 사진 촬영 시 전문 장비를 사용하여 실제 색상과 디자인을 가장 ...
# 15  "개선방안 : 배송 지연 방지를 위한 물류 시스템 최적화 및 제품 손상 방지를 위한...
# 16  "개선방안 : 핵심 부품의 재질을 고급화하여 제품의 전반적인 품질을 향상시킨다.\n...
# 17  "개선방안 : 배송 지연 방지를 위해 배송 파트너사를 확대하고 실시간 추적 시스템을...
# 18  "개선방안 : 실제 색상과 디자인을 정확히 반영하는 고품질 사진 및 360도 영상 ...
# 19  "개선방안 : 제품 상세 페이지에 실제 사용 환경이나 성능에 대한 구체적인 정보(예...
# 20  "개선방안 : 제품 내부에 사용자가 처음 제품을 접했을 때 핵심 기능을 쉽게 익힐 ...
# 21  "개선방안 : 제품 출고 전 기능 테스트 및 품질 관리 프로세스 강화\n고객이 좋아...
# 22  "개선방안 : 실제 제품과 가장 유사한 색감 및 디자인을 구현하기 위해 전문 스튜디...
# 23  "개선방안 : 제품 상세 페이지에 실제 제품의 기능, 성능, 사용 후기 등을 더욱 ...
# 24  "개선방안 : 실시간 배송 추적 시스템 도입 및 지연 시 사전 알림 서비스 제공\n...
# 25  "개선방안 : 경쟁 제품 대비 자사 제품의 강점과 약점을 면밀히 분석하여, 고객이 ...
# 26  "개선방안 : 고객 문의 해결을 위한 최대 응답 및 처리 시간 규정을 수립하고, 이...
# 27  "개선방안 : 제품의 핵심 기능이나 내구성을 강화하기 위한 재료 변경 또는 공정 개...
# 28  "개선방안 : 경쟁 제품 분석을 통해 자사 제품의 강점과 약점을 파악하고, 약점 보...
# 29  "개선방안 : 경쟁사 제품에는 있으나 본 제품에는 없는 핵심 기능을 추가하거나, 기...
# 30  "개선방안 : 제품의 핵심 부품 및 연결 부위를 더 견고한 소재로 교체하고, 구조적...
# 31  "개선방안 : 실제 제품의 색상과 디자인을 가장 정확하게 반영할 수 있도록 전문적인...
# 32  "개선방안 : 고객 문의 해결을 위한 서비스 수준 협약(SLA)을 수립하고, 이를 ...
# 33  "개선방안 : 제품 출고 전 다단계 품질 검수 과정을 도입하여 불량률을 최소화하고,...
# 34  "개선방안 : 제품의 품질 관리 기준을 강화하여 불량률을 낮추고, 고객이 기대하는 ...
# 35  "개선방안 : 다양한 색상 옵션 추가: 현재의 회색이 다용도로 좋지만, 고객의 개성...
# 36  "개선방안 : 제품 사진 촬영 시 전문적인 조명과 환경을 사용하여 실제 제품의 색상...
# 37  "개선방안 : 사용자 인터페이스(UI)를 직관적으로 재설계하고, 주요 기능에 대한 ...
# 38  "개선방안 : 제품 내부에 단계별 튜토리얼 기능 또는 온보딩 가이드를 추가하여 사용...
# 39  "개선방안 : 제품의 주요 기능 사용법을 단계별로 설명하는 짧은 영상 튜토리얼 시리...
# 40  "개선방안 : 제품의 핵심 부품 또는 재료를 더 높은 등급으로 교체하여 전반적인 내...
# 41  "개선방안 : 경쟁사 유사 제품 대비 차별화된 핵심 기능 또는 가치를 추가하여 제품...
# 42  "개선방안 : 제품 출고 전 모든 핵심 기능에 대한 강화된 품질 검수 및 기능 테스...
# 43  "개선방안 : 강화된 품질 관리 및 기능 테스트 프로세스 도입\n고객이 좋아할 법한...
# 44  "개선방안 : 핵심 기능에 대한 출시 전 품질 검증 프로세스를 강화하여, 기능 오작...
# 45  "개선방안 : 출시 전 기능 테스트를 강화하고 품질 관리 프로세스를 개선하여 기능 ...

# %% [markdown]
# 해당 결과를 아래 과정을 통해서 테이블로 생성합니다.

# %%
task4_3_2_query = f"""
  CREATE OR REPLACE TABLE `{PROJECT_ID}.{DATASET_NAME}.{TASK4_3_NEW_TABLE_NAME}` AS (
    SELECT
      generated_output.customer_id,
      generated_output.customer_review_id,
      generated_output.ml_generate_text_result.candidates[0].content.parts[0].text AS improvement_points
    FROM
    ML.GENERATE_TEXT(
      MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_3_MODEL_NAME}`,
      (SELECT
    customer_id,
    customer_review_id,
    CONCAT(
      '''
      다음 리뷰를 참고해서 고객이 불만족한 부분을 개선할 수 있는 구체적인 방안 1개와 고객이 좋아할 법한 상품 특성을 1개 제시해줘 양식은 다음과 같아. 양식을 무조건 지켜서 작성해줘.
      개선방안 :
      고객이 좋아할 법한 특성 :
    참고할 리뷰내용 :
    ''', review_text) AS prompt
    FROM `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}`
    WHERE rating < 3),
    STRUCT(
      0.2 AS temperature,
      2048 AS max_output_tokens )
    ) AS generated_output
  )
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_3_2_query
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 4. 분석 및 보강한 데이터 결합하기

# %%
task4_4_1_query = f"""
  SELECT
    t1.*,
    t2.issue_category
  FROM `{PROJECT_ID}.{DATASET_NAME}.{TASK4_2_NEW_TABLE_NAME}` as t2
  JOIN `{PROJECT_ID}.{DATASET_NAME}.{TASK4_3_NEW_TABLE_NAME}` as t1
  ON t1.customer_review_id = t2.customer_review_id
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_4_1_query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_id  customer_review_id  \
# 0          6418                 212
# 1          5919                 233
# 2          3407                 241
# 3          4264                 205
# 4         10769                 222
# 5          2057                 218
# 6          6355                 219
# 7          6540                 235
# 8          5744                 240
# 9          6531                 243
# 10        10842                 220
# 11         5975                 238
# 12         5480                 228
# 13         5327                 245
# 14        10959                 202
# 15        10669                 234
# 16         2780                 211
# 17        10920                 224
# 18         7170                 250
# 19         4764                 247
# 20         5629                 217
# 21         8206                 216
# 22         5957                 229
# 23         1071                  71
# 24         8887                 215
# 25         9943                 208
# 26        10661                 237
# 27         5516                 221
# 28        10387                 227
# 29         7272                 204
# 30         8533                 226
# 31        10003                 225
# 32         5330                 206
# 33         8710                 248
# 34         9141                 244
# 35         6436                 230
# 36         4462                 239
# 37         5424                 207
# 38         8871                 214
# 39        10500                 236
# 40         8686                 213
# 41        10877                 210
# 42         1195                 231
# 43         4606                 246
# 44         2334                 232
# 45         8496                 223
#
#                                    improvement_points issue_category
# 0   "개선방안 : 제품 생산 과정에 다단계 품질 관리(QC) 시스템을 도입하여 불량률을...           품질불량
# 1   "개선방안 : 경쟁 제품 분석을 통해 고객이 중요하게 생각하는 핵심 기능이나 성능을...          기대미충족
# 2   "개선방안 : 고객 문의 접수 후 24시간 이내 1차 답변 및 72시간 이내 문제 ...           응대문제
# 3   "개선방안 : 사용법을 직관적으로 이해할 수 있도록 제품 내부에 인터랙티브 튜토리얼...          기대미충족
# 4   "개선방안 : 제품 사진 촬영 시 실제 색상과 디자인을 가장 정확하게 반영하도록 전...          기대미충족
# 5   "개선방안 : 앱 내 오류 보고 시스템을 강화하여, 기능 오작동 발생 시 사용자가 ...           품질불량
# 6   "개선방안 : 기능 오류 발생 시 즉각적인 원인 분석 및 패치 업데이트 시스템을 구...           품질불량
# 7   "개선방안 : 모든 제품에 대해 '안심 포장 가이드라인'을 수립하여 완충재 사용을 ...           배송문제
# 8   "개선방안 : 제품의 핵심 부품에 대해 더 강성이 높은 소재를 적용하고, 출고 전 ...           품질불량
# 9   "개선방안 : 핵심 기능에 대한 자동화된 기능 테스트 및 사용자 인수 테스트(UAT...           품질불량
# 10  "개선방안 : 경쟁사 제품과의 상세 비교 분석을 통해 고객이 중요하게 생각하는 핵심...          기대미충족
# 11  "개선방안 : 제품 내부에 직관적인 단계별 사용 가이드(인앱 튜토리얼)를 도입하여 ...          기대미충족
# 12  "개선방안 : 배송 지연 방지를 위해 배송 파트너사를 다변화하고, 모든 제품에 대해...           배송문제
# 13  "개선방안 : 제품의 핵심 기능(예: 성능, 내구성)을 강화하고, 이를 뒷받침하는 ...          기대미충족
# 14  "개선방안 : 배송 지연 방지를 위해 배송 파트너사를 다변화하고, 제품 손상 방지를...           배송문제
# 15  "개선방안 : 경쟁사 제품과의 상세 비교 분석을 통해 고객이 중요하게 생각하는 핵심...          기대미충족
# 16  "개선방안 : 제품의 실제 품질 수준을 상세 페이지에 더욱 투명하게 명시하고, 가격...           품질불량
# 17  "개선방안 : 경쟁사 제품과의 상세 비교 분석을 통해 우리 제품의 강점과 약점을 파...          기대미충족
# 18  "개선방안 : 제품 생산 과정에서 내구성 강화를 위한 재료 테스트 및 스트레스 테스...           품질불량
# 19  "개선방안 : 모든 제품의 포장 과정을 표준화하고, 배송 중 파손을 방지하기 위해 ...           배송문제
# 20  "개선방안 : 제품 상세 페이지에 실제 제품의 색상과 디자인을 다양한 조명(자연광,...          기대미충족
# 21  "개선방안 : 내구성 강화를 위해 더 견고한 소재를 사용하거나 마감 공정을 개선하여...           품질불량
# 22  "개선방안 : 생산 공정의 품질 관리를 강화하여 제품의 내구성과 마감 완성도를 높인...           품질불량
# 23  "개선방안 : 현재 회색 외에도 고객이 다양한 상황에서 활용할 수 있도록, 기존 회...           해당없음
# 24  "개선방안 : 제품 포장 시 에어캡, 완충재 등을 사용하여 제품 손상을 방지하고, ...           배송문제
# 25  "개선방안 : 고객 문의 접수 후 24시간 이내 1차 답변, 72시간 이내 문제 해...           응대문제
# 26  "개선방안 : 제품의 핵심 기능 성능을 강화하고, 이를 1년 무상 보증 정책과 함께...          기대미충족
# 27  "개선방안 : 제품 생산 과정에서 불량률을 줄이기 위한 품질 검수 절차를 강화하고,...           품질불량
# 28  "개선방안 : 실제 제품과 가장 유사한 색감을 구현하기 위해 전문 스튜디오에서 자연...          기대미충족
# 29  "개선방안 : 전문적인 촬영 장비와 색상 보정 작업을 통해 실제 제품의 색상과 디자...          기대미충족
# 30  "개선방안 : 출시 전 핵심 기능에 대한 QA 테스트를 강화하고, 사용자 시나리오 ...           품질불량
# 31  "개선방안 : 고객 문의 접수 후 문제 해결까지의 평균 소요 시간을 단축하기 위한 ...           응대문제
# 32  "개선방안 : 제품 생산 과정에서 품질 관리(QC)를 강화하여 불량률을 낮추고 제품...           품질불량
# 33  "개선방안 : 경쟁사 제품 대비 핵심 기능의 성능을 획기적으로 개선하여 차별점을 부...          기대미충족
# 34  "개선방안 : 실제 제품과 가장 유사한 색감과 질감을 담아낼 수 있도록 전문 스튜디...          기대미충족
# 35  "개선방안 : 제품 출시 전 기능 테스트 프로세스를 강화하고, 사용자 피드백을 신속...           품질불량
# 36  "개선방안 : 제품의 핵심 부품 내구성을 강화하고 생산 공정 중 품질 검수 단계를 ...           품질불량
# 37  "개선방안 : 원자재 품질 향상 및 생산 공정 강화를 통해 제품의 전반적인 품질 수...           품질불량
# 38  "개선방안 : 제품 상세 페이지에 실제 사용 후기나 구체적인 성능 지표를 추가하여 ...          기대미충족
# 39  "개선방안 : 제품 사용 시 주요 기능에 대한 단계별 인터랙티브 튜토리얼 또는 온보...          기대미충족
# 40  "개선방안 : 제품 첫 사용 시 필수 기능 위주로 단계별 인터랙티브 튜토리얼을 제공...          기대미충족
# 41  "개선방안 : 제품의 핵심 기능에 대한 품질 관리 프로세스를 강화하고, 고객 피드백...          기대미충족
# 42  "개선방안 : 핵심 기능 위주로 구성된 짧고 시각적인 퀵 스타트 가이드(Quick ...          기대미충족
# 43  "개선방안 : 제품 출시 전 핵심 기능에 대한 자동화 테스트를 강화하고, 사용자 피...           품질불량
# 44  "개선방안 : 고객 문의 접수 시 1차 상담원의 문제 해결 권한을 확대하고, 복잡한...           응대문제
# 45  "개선방안 : 제품의 핵심 소재나 부품을 더 고급화하여 내구성과 사용감을 개선하고,...           품질불량

# %% [markdown]
# ## 5. 제품 테이블에 제품의 장점, 단점 그리고 특성을 정의한 데이터 추가하기

# %%
task4_5_1_query = f"""
  SELECT
    generated_output.id,
    generated_output.title,
    generated_output.uri,
    generated_output.availability,
    generated_output.categories,
    generated_output.product_id,
    generated_output.price,
    generated_output.average_rating,
    generated_output.review_count,
    generated_output.ml_generate_text_result.candidates[0].content.parts[0].text AS products_details
  FROM
    ML.GENERATE_TEXT(
      MODEL `{PROJECT_ID}.{DATASET_NAME}.{TASK4_5_MODEL_NAME}`,
      (
        SELECT
          *,
          CONCAT(
            '''
            다음 uri를 참고해서 제품의 장점과 단점 그리고 특성을 1개씩 적어줘.
            다음 양식을 무조건 지켜줘
            장점 :
            단점 :
            특성 :
            참고할 uri :
            ''',
            uri
          ) AS prompt
        FROM
          `{PROJECT_ID}.{DATASET_NAME}.products`
      ),
      STRUCT(
        0.2 AS temperature,
        2048 AS max_output_tokens
      )
    ) AS generated_output
"""

# %%
# %%bigquery --project $PROJECT_ID
# $task4_5_1_query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                   id                         title  \
# 0     GGOEGBJC100199          Google Mesh Bag Blue
# 1     GGOEGBRC127999  Google Incognito Techpack V2
# 2     GGOEGBRJ114199       Google Utility BackPack
# 3     GGCOGOCC101199        #IamRemarkable Journal
# 4     GGOEAOAL129199            Android Iconic Pen
# ...              ...                           ...
# 1263  GGOEGAET090513             Google Tee Yellow
# 1264  GGOEGAET090518             Google Tee Yellow
# 1265  GGOEGAET090512             Google Tee Yellow
# 1266  GGOEGAET090515             Google Tee Yellow
# 1267  GGOEGAET090517             Google Tee Yellow
#
#                                                     uri  availability  \
# 0     https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 1     https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 2     https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 3     https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 4     https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# ...                                                 ...           ...
# 1263  https://shop.googlemerchandisestore.com/Google...  OUT_OF_STOCK
# 1264  https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 1265  https://shop.googlemerchandisestore.com/Google...      IN_STOCK
# 1266  https://shop.googlemerchandisestore.com/Google...  OUT_OF_STOCK
# 1267  https://shop.googlemerchandisestore.com/Google...  OUT_OF_STOCK
#
#      categories  product_id   price  average_rating  review_count  \
# 0        [Bags]       23382    7800             3.0           717
# 1        [Bags]       34069  114400             3.6           610
# 2        [Bags]       45465  156000             3.5           641
# 3      [Office]       31736   10400             4.0           847
# 4      [Office]       46816    2275             3.5           716
# ...         ...         ...     ...             ...           ...
# 1263  [Apparel]       21553   28600             4.1           893
# 1264  [Apparel]       41961   28600             3.8           365
# 1265  [Apparel]       49471   28600             4.7            60
# 1266  [Apparel]       31145   28600             4.6           481
# 1267  [Apparel]       28334   28600             4.2           545
#
#                                        products_details
# 0     "장점 : 가볍고 통기성이 좋아 해변, 헬스장 등 다양한 용도로 활용하기 좋다.\n...
# 1     "장점 : 재활용 소재를 사용하여 환경 친화적입니다.\n단점 : 120달러로 가격이...
# 2     "장점 : 다양한 수납공간과 편안한 착용감을 제공합니다.\n단점 : 부분 세척만 가...
# 3     "장점 : 자신의 성과를 기록하고 목표를 설정하며 자신감을 높이는 데 도움을 줍니다...
# 4     "장점 : 부드러운 필기감\n단점 : 일반 펜에 비해 높은 가격\n특성 : 아이코닉...
# ...                                                 ...
# 1263  "장점 : 구글 브랜드에 대한 소속감이나 자부심을 표현할 수 있다.\n단점 : 디자...
# 1264  "장점 : 편안한 착용감 (100% 빗질한 링 스펀 면으로 부드럽고 편안함)\n단점...
# 1265  "장점 : 100% 면 소재로 편안한 착용감\n단점 : 로고 부분 다림질 불가 (장...
# 1266  "장점 : 부드럽고 편안한 착용감\n단점 : 기본 티셔츠치고는 다소 높은 가격\n특...
# 1267  "장점 : 100% 링스펀 코튼 소재로 뛰어난 착용감을 제공합니다.\n단점 : 현재...
#
# [1268 rows x 10 columns]

# %% [markdown]
# ## 6. 분석결과 CSV로 저장하기
#
# 해당 단계에서는 보강한 데이터를 CSV 타입으로 버킷에 저장하는 과정입니다.

# %%
customer_review_enforcement = f"{PROJECT_ID}.{DATASET_NAME}.customer_review_enf_result"

job_config = bigquery.QueryJobConfig(
    destination=customer_review_enforcement,
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE  # 테이블이 있으면 덮어쓰기
)

query_job = client.query(task4_4_1_query, job_config=job_config)
query_job.result()

table_ref = client.dataset(DATASET_NAME).table("customer_review_enf_result")

destination_uri = f"gs://{BUCKET_NAME}/task4_result/customer_review_enf_result.csv"

extract_job_config = bigquery.ExtractJobConfig(
    destination_format=bigquery.DestinationFormat.CSV,
    print_header=True,  # 첫 줄에 헤더(컬럼 이름) 포함
    field_delimiter=',' # 구분자 쉼표(CSV) 사용
)

# 테이블 추출 작업 시작
extract_job = client.extract_table(
    table_ref,
    destination_uri,
    job_config=extract_job_config
)

# 작업 완료 대기
extract_job.result()

print(f"테이블 '{table_ref.path}'의 데이터가 GCS '{destination_uri}'에 CSV 파일로 저장되었습니다.")
# Out:
# 테이블 '/projects/bq-agent-kr/datasets/cymbal/tables/customer_review_enf_result'의 데이터가 GCS 'gs://school_anlayze/task4_result/customer_review_enf_result.csv'에 CSV 파일로 저장되었습니다.

# %%
product_enforcement = f"{PROJECT_ID}.{DATASET_NAME}.product_enf_result"

job_config = bigquery.QueryJobConfig(
    destination=product_enforcement,
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE  # 테이블이 있으면 덮어쓰기
)

query_job = client.query(task4_5_1_query, job_config=job_config)
query_job.result()

table_ref = client.dataset(DATASET_NAME).table("product_enf_result")

destination_uri = f"gs://{BUCKET_NAME}/task4_result/product_enf_result.csv"

extract_job_config = bigquery.ExtractJobConfig(
    destination_format=bigquery.DestinationFormat.CSV,
    print_header=True,  # 첫 줄에 헤더(컬럼 이름) 포함
    field_delimiter=',' # 구분자 쉼표(CSV) 사용
)

# 테이블 추출 작업 시작
extract_job = client.extract_table(
    table_ref,
    destination_uri,
    job_config=extract_job_config
)

# 작업 완료 대기
extract_job.result()

print(f"테이블 '{table_ref.path}'의 데이터가 GCS '{destination_uri}'에 CSV 파일로 저장되었습니다.")
# Out:
# 테이블 '/projects/bq-agent-kr/datasets/cymbal/tables/product_enf_result'의 데이터가 GCS 'gs://school_anlayze/task4_result/product_enf_result.csv'에 CSV 파일로 저장되었습니다.
